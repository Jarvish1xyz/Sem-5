# %% [markdown]
# # ====> Bank Loan Default Prediction Using Machine Learning

# %% [markdown]
# #### Banks provide loans to customers, but some customers fail to repay them, causing financial losses. Predicting whether a customer is likely to default before approving a loan can help banks reduce risk and make better lending decisions.
#
# #### Objective:
# #### Develop a machine learning model that predicts whether a customer will default on a loan based on their personal, financial, and loan-related information.
# #### ===========================================================================================

# %% [markdown]
# #### => Dataset Summary
# #### Dataset Name: Loan Default Prediction Dataset
#
# #### Domain: Banking / Finance
#
# #### Target Variable: Default (or Loan_Status, depending on the dataset)
#
# #### 0 = No Default
# #### 1 = Default
# #### ===========================================================================================
# #### Feature Categories
# #### ===========================================================================================
#
# #### => Numerical Features
# #### - Age
# #### - Income
# #### - LoanAmount
# #### - CreditScore
# #### - MonthsEmployed
# #### - NumCreditLines
# #### - InterestRate
# #### - LoanTerm
# #### - DTIRatio
#
#
# #### => Categorical Features
# #### - Education
# #### - EmploymentType
# #### - MaritalStatus
# #### - HasMortgage
# #### - HasDependents
# #### - LoanPurpose
# #### - HasCoSigner
#
#
# #### => Identifier
# #### - LoanID
#
#
# #### => Target Variable
# #### - Default
#
#
# #### => Total Features
# #### - 1 Identifier: LoanID
# #### - 9 Numerical Features
# #### - 7 Categorical Features
# #### - 1 Target Variable: Default
# #### Total Columns = 18
#
# #### ===========================================================================================

# %% [markdown]
# => Feature
# | Feature        | Description                                       | Type                 |
# | -------------- | ------------------------------------------------- | -------------------- |
# | LoanID         | Unique loan ID                                    | Categorical          |
# | Age            | Age of the applicant                              | Numerical            |
# | Income         | Annual income of the applicant                    | Numerical            |
# | LoanAmount     | Amount of loan requested                          | Numerical            |
# | CreditScore    | Applicant's credit score                          | Numerical            |
# | MonthsEmployed | Total months employed                             | Numerical            |
# | NumCreditLines | Number of active credit lines                     | Numerical            |
# | InterestRate   | Loan interest rate (%)                            | Numerical            |
# | LoanTerm       | Loan repayment period (months)                    | Numerical            |
# | DTIRatio       | Debt-to-Income ratio                              | Numerical            |
# | Education      | Highest education level                           | Categorical          |
# | EmploymentType | Type of employment                                | Categorical          |
# | MaritalStatus  | Marital status                                    | Categorical          |
# | HasMortgage    | Whether the applicant has a mortgage              | Categorical (Yes/No) |
# | HasDependents  | Whether the applicant has dependents              | Categorical (Yes/No) |
# | LoanPurpose    | Purpose of the loan                               | Categorical          |
# | HasCoSigner    | Whether the loan has a co-signer                  | Categorical (Yes/No) |
# | **Default**    | **Target variable (0 = No Default, 1 = Default)** | **Target**           |
#
#
# #### ===========================================================================================

# %%
import pandas as pd

df = pd.read_csv("Loan_default.csv")
#1
df.head(df.shape[0])
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96   56   85994       50587          520              80
# 1       HPSK72WA7R   69   50432      124440          458              15
# 2       C1OZ6DPJ8Y   46   84208      129188          451              26
# 3       V2KKSFM3UN   32   31713       44799          743               0
# 4       EY08JDHTZP   60   20437        9139          633               8
# ...            ...  ...     ...         ...          ...             ...
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
#2
df.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255347.000000  255347.000000  255347.000000  255347.000000
# mean       43.498306   82499.304597  127578.865512     574.264346
# std        14.990258   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
#3
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
# ...

# %%
#4
df.shape
# Out:
# (255347, 18)

# %%
#5
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
#6
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %%
#7
print(df.head(10))
# Out:
#        LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0  I38PQUQS96   56   85994       50587          520              80
# 1  HPSK72WA7R   69   50432      124440          458              15
# 2  C1OZ6DPJ8Y   46   84208      129188          451              26
# 3  V2KKSFM3UN   32   31713       44799          743               0
# 4  EY08JDHTZP   60   20437        9139          633               8
# 5  A9S62RQ7US   25   90298       90448          720              18
# 6  H8GXPAOS71   38  111188      177025          429              80
# 7  0HGZQKJ36W   56  126802      155511          531              67
# 8  1R0N3LGNRJ   36   42053       92357          827              83
# 9  CM9L1GTT2P   40  132784      228510          480             114
#
#    NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0               4         15.23        36      0.44   Bachelor's
# 1               1          4.81        60      0.68     Master's
# ...

# %%
#8
print(df.tail(10))
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 255337  DSL4O0KAWD   64   73743      140354          300               0
# 255338  6V8S5IUS63   68   21711      168231          352              78
# 255339  O6SWO6CBGB   51   69492      122962          348              66
# 255340  48LOOK4VR1   41   61809      119238          444              34
# 255341  AKXAXQN7PG   40  129890      116119          701              38
# 255342  8C6S86ESGC   19   37979      210682          541             109
# 255343  98R4KDHNND   32   51953      189899          511              14
# 255344  XQK1UUUNGP   56   84820      208294          597              70
# 255345  JAO28CPL4H   42   85109       60575          809              40
# 255346  ZTH91CGL0B   62   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 255337               2          4.12        12      0.24          PhD
# ...

# %%
#9
df['Default'].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
#10
df['LoanAmount'].head(1)
# Out:
# 0    50587
# Name: LoanAmount, dtype: int64

# %%
#11
print(df["LoanAmount"].sum())
# Out:
# 32576880572
