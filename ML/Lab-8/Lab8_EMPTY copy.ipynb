# %% [markdown]
# <a href='https://www.darshan.ac.in/'> <img src='https://www.darshan.ac.in/Content/media/DU_Logo.svg' width="250" height="300"/></a>
# <pre>
# <center><b><h1>Machine Learning - 2301CS621</b></center>
#
# <center><b><h1>Lab - 8</b></center>
# <pre>

# %% [markdown]
# # import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import diabetes.csv data ser using sklearn

# %%
df = pd.read_csv('diabetes.csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age       Outcome
# 0                       0.627   50      Diabetic
# ...

# %% [markdown]
# # Check the distribution of the target

# %%
y = df.Outcome
y.value_counts()
# Out:
# Outcome
# Non Diabetic    500
# Diabetic        268
# Name: count, dtype: int64

# %% [markdown]
# # Replace zeros with NaN for specific columns

# %%
(df==0).sum()
# Out:
# Pregnancies                 111
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
changeColumn = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

# %%
df[changeColumn] = df[changeColumn].replace(0, np.nan)

# %%
(df==0).sum()
# Out:
# Pregnancies                 111
# Glucose                       0
# BloodPressure                 0
# SkinThickness                 0
# Insulin                       0
# BMI                           0
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# # Check for missing values

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# # Fill missing values with median

# %%
for col in changeColumn:
    df[col] = df[col].fillna(df[col].median())

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# # Visualize Distributions

# %%
import seaborn as sns

# %%
df.hist(figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %%
df.plot(kind='box', subplots=True, layout=(3, 3), figsize=(14, 10))
plt.tight_layout()
plt.show()

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age       Outcome
# 0                     0.627   50      Diabetic
# 1                     0.351   31  Non Diabetic
# 2                     0.672   32      Diabetic
# 3                     0.167   21  Non Diabetic
# 4                     2.288   33      Diabetic

# %% [markdown]
# # Convert Targer data into interger code

# %%
df['Outcome'] = df['Outcome'].map({'Diabetic': 1, 'Non Diabetic': 0})

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6    148.0           72.0           35.0    125.0  33.6
# 1              1     85.0           66.0           29.0    125.0  26.6
# 2              8    183.0           64.0           29.0    125.0  23.3
# 3              1     89.0           66.0           23.0     94.0  28.1
# 4              0    137.0           40.0           35.0    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10    101.0           76.0           48.0    180.0  32.9
# 764            2    122.0           70.0           27.0    125.0  36.8
# 765            5    121.0           72.0           23.0    112.0  26.2
# 766            1    126.0           60.0           29.0    125.0  30.1
# 767            1     93.0           70.0           31.0    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %% [markdown]
# # Divide the data into input and output

# %%
x = df.drop('Outcome', axis=1)

# %%
y = df.Outcome

# %% [markdown]
# # Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# # Create Model

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import plot_tree

# %%
dtreeModel = DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# # Fitting DecisionTreeClassifier   on dataset

# %%
dtreeModel.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=2)

# %% [markdown]
# # Display Decision Tree

# %%
plt.figure(figsize=(15,20))
plot_tree(dtreeModel, filled=True, feature_names=x, class_names=y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\HP\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: np.int64(1)
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# # Predict the x_test

# %%
dtreeModel.predict(x_test)

# %% [markdown]
# # Display Training Accuracy

# %%
dtreeModel.score(x_train, y_train)

# %% [markdown]
# # Display Test Accuracy

# %%
dtreeModel.score(x_test, y_test)
